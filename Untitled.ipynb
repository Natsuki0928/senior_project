# %%
import xml.etree.ElementTree as ET
import pandas as pd

def xml2df(xml_data):
    root = ET.XML(xml_data) # element tree
    all_records = []
    for i, child in enumerate(root):
        record = {}
        for subchild in child:
            record[subchild.tag] = subchild.text
        all_records.append(record)
    df = pd.DataFrame(all_records)
    return df

# load XML to dataframe (gotta be small)
xml_data = open('data/P20-12_04.xml').read()
df = xml2df(xml_data)
df.tail()
# Out:
#      {http://www.opengis.net/gml/3.2}EnvelopeWithTimePeriod  \
# 3945                                                NaN
# 3946                                                NaN
# 3947                                                NaN
# 3948                                                NaN
# 3949                                                NaN
#
#      {http://www.opengis.net/gml/3.2}pos  \
# 3945                                 NaN
# 3946                                 NaN
# 3947                                 NaN
# 3948                                 NaN
# 3949                                 NaN
#
#       {http://nlftp.mlit.go.jp/ksj/schemas/ksj-app}position  \
# 3945                                                NaN
# 3946                                                NaN
# 3947                                                NaN
# 3948                                                NaN
# 3949                                                NaN
#
#      {http://nlftp.mlit.go.jp/ksj/schemas/ksj-app}administrativeAreaCode  \
# 3945                                              04606
# 3946                                              04606
# 3947                                              04606
# 3948                                              04212
# 3949                                              04321
#
#      {http://nlftp.mlit.go.jp/ksj/schemas/ksj-app}name  \
# 3945                                    名足地区コミュニティセンター
# 3946                                          林際生活センター
# 3947                                           林生活センター
# 3948                                          老人福祉センター
# 3949                                            大河原小学校
#
#      {http://nlftp.mlit.go.jp/ksj/schemas/ksj-app}address  \
# 3945                                  宮城県本吉郡南三陸町歌津字名足72
# 3946                              宮城県本吉郡南三陸町入谷字山の神平19-3
# 3947                                宮城県本吉郡南三陸町志津川字林87-1
# 3948                             宮城県登米市津山町柳津字黄牛田高畑36番地5
# 3949                                    宮城県柴田郡大河原町字町100
#
#      {http://nlftp.mlit.go.jp/ksj/schemas/ksj-app}facilityType  \
# 3945                                             指定避難場所
# 3946                                             指定避難場所
# 3947                                             指定避難場所
# 3948                                               避難場所
# 3949                                          避難可能な公共施設
#
#      {http://nlftp.mlit.go.jp/ksj/schemas/ksj-app}seatingCapacity  \
# 3945                                                 -1
# 3946                                                 -1
# 3947                                                 -1
# 3948                                                 -1
# 3949                                               1500
#
#      {http://nlftp.mlit.go.jp/ksj/schemas/ksj-app}facilityScale  \
# 3945                                                 -1
# 3946                                                 -1
# 3947                                                 -1
# 3948                                                 -1
# 3949                                              13078
#
#      {http://nlftp.mlit.go.jp/ksj/schemas/ksj-app}hazardClassification
# 3945                                           \n
# 3946                                           \n
# 3947                                           \n
# 3948                                           \n
# 3949                                           \n
